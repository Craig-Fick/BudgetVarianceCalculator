# %% [markdown]
# # Daily Budget Variance Calculator

# %%
from tkinter import *
import tkinter.messagebox
from ttkthemes import ThemedTk
import pandas as pd

# build schedule df from scratch - We will utilize 5 employees on a one week schedule
# Establish employee, pay, and hours for one week.
data = [['Tim White', 15.00,0,8,8,8,8,8,0], ['Charles Higgins', 16.50,8,0,0,0,0,0,8], ['Earl Palmer', 17.25,8,0,0,0,0,0,8],['Ian Snider', 14.50,0,8,8,8,8,8,0], ['Francis Little', 14.50,0,8,8,8,8,8,0]]
 
# Create the pandas DataFrame
df = pd.DataFrame(data, columns = ['NAME', 'PAY_RATE', 'SUNDAY', 'MONDAY','TUESDAY', 'WEDNESDAY', 'THURSDAY', 'FRIDAY', 'SATURDAY'])
 
# build GUI with pages
# multiple pages
def page1(main):
    page = Frame(main)
    main.configure(bg='Light Gray')
    main.title("Daily Budget Variance Calculator")
    
    
    # establish frames within grid
    frame1 = LabelFrame(main, bg="light gray", borderwidth = 0, highlightthickness = 0)
    frame1.grid(row=0, column=0)
    Label(frame1, text = 'This tool directly plugs in a schedudle to quickly calculate current hours and pay.', bg = 'light gray').grid(row = 0, column = 0, pady = 20)

    

    Label(frame1, text = 'A schedule has been preinstalled and a sample can be observed below.', bg = 'light gray').grid(row = 1, column = 0)
    Button(frame1, text = 'NEXT PAGE', command = changepage).grid(row = 2, column = 0, pady = 30)
    
    text = Text(pady = 30, padx = 30, bg = 'light gray', width = 75, height = 10, borderwidth = 0, highlightthickness = 0)
    text.insert(END, str(df.iloc[:,1:10]))
    text.grid(row=1, column=0)
    


def page2(main):
    # Functions
    # Calculations for everything
    def calc():     
        # get entries
        day = 0
        day5 = variable.get()
        if day5 == "SUNDAY":
            day = 1
        if day5 == "MONDAY":
            day = 2
        if day5 == "TUESDAY":
            day = 3
        if day5 == "WEDNESDAY":
            day = 4    
        if day5 == "THURSDAY":
            day = 5
        if day5 == "FRIDAY":
            day = 6
        if day5 == "SATURDAY":
            day = 7
        day0 = int(day)
        emp1 = float(hour1.get())
        emp2 = float(hour2.get())
        emp3 = float(hour3.get())
        emp4 = float(hour4.get())
        emp5 = float(hour5.get())
        pay1 = df.PAY_RATE
    
        #calculations
        # total hours + overtime
        total_hour = float(emp1+emp2+emp3+emp4+emp5)
        
        
        # total pay + overtime
        tp1 = 0
        tp2 = 0
        tp3 = 0
        tp4 = 0
        tp5 = 0
        oth1 = 0
        oth2 = 0
        oth3 = 0
        oth4 = 0
        oth5 = 0
        otp1 = 0
        otp2 = 0
        otp3 = 0
        otp4 = 0
        otp5 = 0
        if emp1 > 40: 
            oth1 = emp1 - 40
            otp1 = (((emp1-40)* df.PAY_RATE[0])*1.5)
            tp1 = ((emp1 * df.PAY_RATE[0]) + (((emp1-40)* df.PAY_RATE[0])*1.5))
        if emp2 > 40:
            oth2 = emp2-40
            otp2 =(((emp2-40)* df.PAY_RATE[1])*1.5)
            tp2 = ((emp2 * df.PAY_RATE[1]) + (((emp2-40)* df.PAY_RATE[1])*1.5))
        if emp3 > 40:
            oth3 = emp3-40
            otp3 = (((emp3-40)* df.PAY_RATE[2])*1.5)
            tp3 = ((emp3 * df.PAY_RATE[2]) + (((emp3-40)* df.PAY_RATE[2])*1.5))
        if emp4 > 40: 
            oth4 = emp4-40
            otp4 = (((emp4-40)* df.PAY_RATE[3])*1.5)
            tp4 = ((emp4 * df.PAY_RATE[3]) + (((emp4-40)* df.PAY_RATE[3])*1.5))
        if emp5 > 40:
            oth5 = emp5-40
            otp5 = (((emp5-40)* df.PAY_RATE[4])*1.5)
            tp5 = ((emp5 * df.PAY_RATE[4]) + (((emp5-40)* df.PAY_RATE[4])*1.5))
        if emp1 <= 40: 
            tp1 = emp1 * df.PAY_RATE[0] 
        if emp2 <= 40:            
            tp2 = emp2 * df.PAY_RATE[1]
        if emp3 <= 40:            
            tp3 = emp3 * df.PAY_RATE[2]
        if emp4 <= 40:           
            tp4 = emp4 * df.PAY_RATE[3]
        if emp5 <= 40:            
            tp5 = emp5 * df.PAY_RATE[4]
        # total pay based on hours
        total_pay = float(tp1+tp2+tp3+tp4+tp5)
        
        # overtime 
        # hours
        total_oth = float(oth1+oth2+oth3+oth4+oth5)
        # pay
        total_otp = float(otp1+otp2+otp3+otp4+otp5)
        
        # current budget
        # pay
        budget_pay = 0
        if day0 == 1:
            budget_pay = sum(df.PAY_RATE * df.SUNDAY)
        if day0 == 2:
            budget_pay = sum(df.PAY_RATE * (df.SUNDAY + df.MONDAY))
        if day0 == 3:
            budget_pay = sum(df.PAY_RATE * (df.SUNDAY + df.MONDAY + df.TUESDAY))
        if day0 == 4:
            budget_pay = sum(df.PAY_RATE * (df.SUNDAY + df.MONDAY + df.TUESDAY + df.WEDNESDAY))
        if day0 == 5:
            budget_pay = sum(df.PAY_RATE * (df.SUNDAY + df.MONDAY + df.TUESDAY + df.WEDNESDAY + df.THURSDAY))
        if day0 == 6:
            budget_pay = sum(df.PAY_RATE * (df.SUNDAY + df.MONDAY + df.TUESDAY + df.WEDNESDAY + df.THURSDAY + df.FRIDAY))
        if day0 == 7:
            budget_pay = sum(df.PAY_RATE * (df.SUNDAY + df.MONDAY + df.TUESDAY + df.WEDNESDAY + df.THURSDAY + df.FRIDAY + df.SATURDAY))
        
        # hours
        budget_hours = 0
        if day0 == 1:
            budget_hours = float(sum(df.SUNDAY))
        if day0 == 2:
            budget_hours = float(sum(df.SUNDAY + df.MONDAY))
        if day0 == 3:
            budget_hours = float(sum(df.SUNDAY + df.MONDAY + df.TUESDAY))
        if day0 == 4:
            budget_hours = float(sum(df.SUNDAY + df.MONDAY + df.TUESDAY + df.WEDNESDAY))
        if day0 == 5:
            budget_hours = float(sum(df.SUNDAY + df.MONDAY + df.TUESDAY + df.WEDNESDAY + df.THURSDAY))
        if day0 == 6:
            budget_hours = float(sum(df.SUNDAY + df.MONDAY + df.TUESDAY + df.WEDNESDAY + df.THURSDAY + df.FRIDAY))
        if day0 == 7:
            budget_hours = float(sum(df.SUNDAY + df.MONDAY + df.TUESDAY + df.WEDNESDAY + df.THURSDAY + df.FRIDAY + df.SATURDAY))
    
        # available hours
        hour_avl = budget_hours - total_hour
        # available pay
        pay_avl = budget_pay - total_pay
        
        
        # employees list that are over
        empot1 = 0
        empot2 = 0
        empot3 = 0
        empot4 = 0
        empot5 = 0
        if day0 == 1:
            empot1 = -(df.SUNDAY[0] - emp1)
            empot2 = -(df.SUNDAY[1] - emp2)
            empot3 = -(df.SUNDAY[2] - emp3)
            empot4 = -(df.SUNDAY[3] - emp4)
            empot5 = -(df.SUNDAY[4] - emp5)
        if day0 == 2:
            empot1 = -((df.SUNDAY[0]+ df.MONDAY[0]) - emp1)
            empot2 = -((df.SUNDAY[1]+ df.MONDAY[1]) - emp2)
            empot3 = -((df.SUNDAY[2]+ df.MONDAY[2]) - emp3)
            empot4 = -((df.SUNDAY[3]+ df.MONDAY[3]) - emp4)
            empot5 = -((df.SUNDAY[4]+ df.MONDAY[4]) - emp5)
        if day0 == 3:
            empot1 = -((df.SUNDAY[0]+ df.MONDAY[0]+ df.TUESDAY[0]) - emp1)
            empot2 = -((df.SUNDAY[1]+ df.MONDAY[1]+ df.TUESDAY[1]) - emp2)
            empot3 = -((df.SUNDAY[2]+ df.MONDAY[2]+ df.TUESDAY[2]) - emp3)
            empot4 = -((df.SUNDAY[3]+ df.MONDAY[3]+ df.TUESDAY[3]) - emp4)
            empot5 = -((df.SUNDAY[4]+ df.MONDAY[4]+ df.TUESDAY[4]) - emp5)
        if day0 == 4:
            empot1 = -((df.SUNDAY[0]+ df.MONDAY[0]+ df.TUESDAY[0]+ df.WEDNESDAY[0]) - emp1)
            empot2 = -((df.SUNDAY[1]+ df.MONDAY[1]+ df.TUESDAY[1]+ df.WEDNESDAY[1]) - emp2)
            empot3 = -((df.SUNDAY[2]+ df.MONDAY[2]+ df.TUESDAY[2]+ df.WEDNESDAY[2]) - emp3)
            empot4 = -((df.SUNDAY[3]+ df.MONDAY[3]+ df.TUESDAY[3]+ df.WEDNESDAY[3]) - emp4)
            empot5 = -((df.SUNDAY[4]+ df.MONDAY[4]+ df.TUESDAY[4]+ df.WEDNESDAY[4]) - emp5)
        if day0 == 5:
            empot1 = -((df.SUNDAY[0]+ df.MONDAY[0]+ df.TUESDAY[0]+ df.WEDNESDAY[0]+ df.THURSDAY[0]) - emp1)
            empot2 = -((df.SUNDAY[1]+ df.MONDAY[1]+ df.TUESDAY[1]+ df.WEDNESDAY[1]+ df.THURSDAY[1]) - emp2)
            empot3 = -((df.SUNDAY[2]+ df.MONDAY[2]+ df.TUESDAY[2]+ df.WEDNESDAY[2]+ df.THURSDAY[2]) - emp3)
            empot4 = -((df.SUNDAY[3]+ df.MONDAY[3]+ df.TUESDAY[3]+ df.WEDNESDAY[3]+ df.THURSDAY[3]) - emp4)
            empot5 = -((df.SUNDAY[4]+ df.MONDAY[4]+ df.TUESDAY[4]+ df.WEDNESDAY[4]+ df.THURSDAY[4]) - emp5)
        if day0 == 6:
            empot1 = -((df.SUNDAY[0]+ df.MONDAY[0]+ df.TUESDAY[0]+ df.WEDNESDAY[0]+ df.THURSDAY[0]+ df.FRIDAY[0]) - emp1)
            empot2 = -((df.SUNDAY[1]+ df.MONDAY[1]+ df.TUESDAY[1]+ df.WEDNESDAY[1]+ df.THURSDAY[1]+ df.FRIDAY[1]) - emp2)
            empot3 = -((df.SUNDAY[2]+ df.MONDAY[2]+ df.TUESDAY[2]+ df.WEDNESDAY[2]+ df.THURSDAY[2]+ df.FRIDAY[2]) - emp3)
            empot4 = -((df.SUNDAY[3]+ df.MONDAY[3]+ df.TUESDAY[3]+ df.WEDNESDAY[3]+ df.THURSDAY[3]+ df.FRIDAY[3]) - emp4)
            empot5 = -((df.SUNDAY[4]+ df.MONDAY[4]+ df.TUESDAY[4]+ df.WEDNESDAY[4]+ df.THURSDAY[4]+ df.FRIDAY[4]) - emp5)
        if day0 == 7:
            empot1 = -((df.SUNDAY[0]+ df.MONDAY[0]+ df.TUESDAY[0]+ df.WEDNESDAY[0]+ df.THURSDAY[0]+ df.FRIDAY[0]+ df.SATURDAY[0]) - emp1)
            empot2 = -((df.SUNDAY[1]+ df.MONDAY[1]+ df.TUESDAY[1]+ df.WEDNESDAY[1]+ df.THURSDAY[1]+ df.FRIDAY[1]+ df.SATURDAY[1]) - emp2)
            empot3 = -((df.SUNDAY[2]+ df.MONDAY[2]+ df.TUESDAY[2]+ df.WEDNESDAY[2]+ df.THURSDAY[2]+ df.FRIDAY[2]+ df.SATURDAY[2]) - emp3)
            empot4 = -((df.SUNDAY[3]+ df.MONDAY[3]+ df.TUESDAY[3]+ df.WEDNESDAY[3]+ df.THURSDAY[3]+ df.FRIDAY[3]+ df.SATURDAY[3]) - emp4)
            empot5 = -((df.SUNDAY[4]+ df.MONDAY[4]+ df.TUESDAY[4]+ df.WEDNESDAY[4]+ df.THURSDAY[4]+ df.FRIDAY[4]+ df.SATURDAY[4]) - emp5)
            

        Label(frame5, text = "OVER/UNDER HOURS", bg = 'light gray', font='Helvetica 9 bold').grid(row=2, column=3, pady=10, padx=10)
        label21 = Label(frame5, text= "{}".format(empot1), bg = 'light gray')
        label21.grid(row=3, column=3, sticky = W, padx=55, pady= 5)
        label22 = Label(frame5, text= "{}".format(empot2), bg = 'light gray')
        label22.grid(row=4, column=3, sticky = W, padx=55, pady= 5)
        label23 = Label(frame5, text= "{}".format(empot3), bg = 'light gray')
        label23.grid(row=5, column=3, sticky = W, padx=55, pady= 5)
        label24 = Label(frame5, text= "{}".format(empot4), bg = 'light gray')
        label24.grid(row=6, column=3, sticky = W, padx=55, pady= 5)
        label25 = Label(frame5, text= "{}".format(empot5), bg = 'light gray')
        label25.grid(row=7, column=3, sticky = W, padx=55, pady= 5)
    
    
        # Pay
        Label(frame5, text = "TOTAL PAY", bg = 'light gray', font='Helvetica 9 bold', anchor = "center").grid(row=2, column=2)
        label2 = Label(frame5, text= "{}".format(tp1), bg = 'light gray', anchor = "center")
        label2.grid(row=3, column=2, sticky = W, padx=30, pady= 5)
        label3 = Label(frame5, text= "{}".format(tp2), bg = 'light gray', anchor = "center")
        label3.grid(row=4, column=2, sticky = W, padx=30, pady= 5)
        label4 = Label(frame5, text= "{}".format(tp3), bg = 'light gray', anchor = "center")
        label4.grid(row=5, column=2, sticky = W, padx=30, pady= 5)
        label5 = Label(frame5, text= "{}".format(tp4), bg = 'light gray', anchor = "center")
        label5.grid(row=6, column=2, sticky = W, padx=30, pady= 5)
        label6 = Label(frame5, text= "{}".format(tp5), bg = 'light gray', anchor = "center")
        label6.grid(row=7, column=2, sticky = W, padx=30, pady= 5)
        
        # Labels
        # Bottom info
        frame4 = LabelFrame(main, bg="dark gray")
        frame4.grid(row=3, column=0, pady=10, padx=10)        
        label0 = Label(frame4, text= "BUDGETED HOURS:", bg = 'dark gray', font='Helvetica 9 bold')
        label0.grid(row=0, column=0, sticky = W, pady=5, padx=40)
        label1 = Label(frame4, text= "{}".format(budget_hours), bg = 'dark gray')
        label1.grid(row=0, column=1, sticky = W, pady=5, padx=10)   
        label7 = Label(frame4, text= "BUDGETED PAY:", bg = 'dark gray', font='Helvetica 9 bold')
        label7.grid(row=1, column=0, sticky = W, pady=5, padx=40)
        label8 = Label(frame4, text= "{}".format(budget_pay), bg = 'dark gray')
        label8.grid(row=1, column=1, sticky = W, pady=5, padx=10)     
        label9 = Label(frame4, text= "TOTAL HOURS USED:", bg = 'dark gray', font='Helvetica 9 bold')
        label9.grid(row=2, column=0, sticky = W, pady=5, padx=40)
        label10 = Label(frame4, text= "{}".format(total_hour), bg = 'dark gray')
        label10.grid(row=2, column=1, sticky = W, pady=5, padx=10) 
        label11 = Label(frame4, text= "TOTAL PAY USED:", bg = 'dark gray', font='Helvetica 9 bold')
        label11.grid(row=3, column=0, sticky = W, pady=5, padx=40)
        label12 = Label(frame4, text= "{}".format(total_pay), bg = 'dark gray')
        label12.grid(row=3, column=1, sticky = W, pady=5, padx=10) 
        label13 = Label(frame4, text= "HOURS AVAILABLE:", bg = 'dark gray', font='Helvetica 9 bold')
        label13.grid(row=4, column=0, sticky = W, pady=5, padx=40)
        label14 = Label(frame4, text= "{}".format(hour_avl), bg = 'dark gray')
        label14.grid(row=4, column=1, sticky = W, pady=5, padx=10) 
        label15 = Label(frame4, text= "PAY AVAILABLE:", bg = 'dark gray', font='Helvetica 9 bold')
        label15.grid(row=5, column=0, sticky = W, pady=5, padx=40)
        label16 = Label(frame4, text= "{}".format(pay_avl), bg = 'dark gray')
        label16.grid(row=5, column=1, sticky = W, pady=5, padx=10) 
        label17 = Label(frame4, text= "OVERTIME HOURS:", bg = 'dark gray', font='Helvetica 9 bold')
        label17.grid(row=6, column=0, sticky = W, pady=5, padx=40)
        label18 = Label(frame4, text= "{}".format(total_oth), bg = 'dark gray')
        label18.grid(row=6, column=1, sticky = W, pady=5, padx=10) 
        label19 = Label(frame4, text= "OVERTIME PAY:", bg = 'dark gray', font='Helvetica 9 bold')
        label19.grid(row=7, column=0, sticky = W, pady=5, padx=40)
        label20 = Label(frame4, text= "{}".format(total_otp), bg = 'dark gray')
        label20.grid(row=7, column=1, sticky = W, pady=5, padx=10) 

    # to auto-populate the entry boxes for testing via test button
    def test():
        a = 1
        b = 8
        c = 4
        d = 8
        e = 8
        f = 0
        hour1.insert(0, b)
        hour2.insert(0, c)
        hour3.insert(0, d)
        hour4.insert(0, e)
        hour5.insert(0, f)
    
    #page 2 layout    
    page = Frame(main)
    page.grid()
    main.geometry("650x700")
    main.configure(bg='Light Gray')
    main.title("Daily Budget Variance Calculator")
    
    # text
    frame5 = LabelFrame(main, bg="light gray", borderwidth = 0, highlightthickness = 0)
    frame5.grid(row=0, column=0, padx= 15, pady= 15)  
    
    # drop down menu for day of the week
    OptionList = [
        "SUNDAY",
        "MONDAY",
        "TUESDAY",
        "WEDNESDAY",
        "THURSDAY",
        "FRIDAY",
        "SATURDAY"
        ] 
    variable = StringVar(frame5)
    variable.set(OptionList[0])
    opt = OptionMenu(frame5, variable, *OptionList)
    opt.config()
    opt.grid(row=1, column=1, padx= 20, pady= 5)

    
    Label(frame5, text = "SELECT DAY OF WEEK:", bg = 'light gray', font='Helvetica 9 bold').grid(row=1, padx= 5, pady= 20)
    frame9 = LabelFrame(main, bg="light gray", borderwidth = 0, highlightthickness = 0)
    frame9.grid(row=1, column=0, padx= 15, pady= 15) 
    Label(frame5, text = "EMPLOYEES", bg = 'light gray', font='Helvetica 9 bold').grid(row=2, padx= 5, pady= 5)
    Label(frame5, text = "Tim White", bg = 'light gray').grid(row=3, padx= 5, pady= 5)
    Label(frame5, text = "Charles Higgins", bg = 'light gray').grid(row=4, padx= 5, pady= 5)
    Label(frame5, text = "Earl Palmer", bg = 'light gray').grid(row=5, padx= 5, pady= 5)
    Label(frame5, text = "Ian Snider", bg = 'light gray').grid(row=6, padx= 5, pady= 5)
    Label(frame5, text = "Francis Little", bg = 'light gray').grid(row=7, padx= 5, pady= 5)
    Label(frame5, text = "ENTER CURRENT HOURS", bg = 'light gray', font='Helvetica 9 bold').grid(row=2, column=1, padx= 30, pady= 5)
    # Label(frame5, text = "INFORMATION WILL POPULATE BELOW", bg = 'light gray', font='Helvetica 9 bold').grid(row=8, column=0, padx= 10, pady= 10)

    # entry
    #day = Entry(frame5, width = 10)
    hour1 = Entry(frame5, width = 10)
    hour2 = Entry(frame5, width = 10)
    hour3 = Entry(frame5, width = 10)
    hour4 = Entry(frame5, width = 10)
    hour5 = Entry(frame5, width = 10)

    # buttons
    frame6 = LabelFrame(main, bg="light gray", borderwidth = 0, highlightthickness = 0)
    frame6.grid(row=2, column=0)  
    Button(frame6, text = "BACK", command = changepage).grid(row = 0, column = 0)
    Button(frame6, text="RESET", command=reset).grid(row = 0, column=1, sticky = W, pady=30)
    Button(frame6, text="CALCULATE", command=calc).grid(row = 0,column=2, sticky = W, pady=30) 
    #Button(frame6, text="EXAMPLE", command=test).grid(row = 0, column=3, sticky = W, pady=30)
           
    # layout
    #day.grid(row=1, column=1, padx= 20, pady= 5)
    hour1.grid(row=3, column=1, padx= 20, pady= 5)
    hour2.grid(row=4, column=1, padx= 20, pady= 5)
    hour3.grid(row=5, column=1, padx= 20, pady= 5)
    hour4.grid(row=6, column=1, padx= 20, pady= 5)
    hour5.grid(row=7, column=1, padx= 20, pady= 5)


def changepage():
    global pagenum, main
    for widget in main.winfo_children():
        widget.destroy()
    if pagenum == 1:
        page2(main)
        pagenum = 2
    else:
        page1(main)
        pagenum = 1
        
def reset():
    global pagenum, main
    for widget in main.winfo_children():
        widget.destroy()
    if pagenum == 2:
        page2(main)
        pagenum = 2
    else:
        page1(main)
        pagenum = 1


# Intitate Main GUI build
pagenum = 1
main = Tk()
page1(main)
main.title("Daily Budget Variance Calculator")





mainloop()
